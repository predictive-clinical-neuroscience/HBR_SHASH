# %%
from pcntoolkit.util.hbr_utils import *
import scipy

import os
import pickle
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import pcntoolkit as ptk
from itertools import product
from functools import reduce
from pcntoolkit.model.SHASH import SHASHb, SHASH, SHASHo
from pcntoolkit.util.utils import scaler
from scipy.stats import gaussian_kde
import pymc3 as pm
import scipy.special as spp
import arviz as av
from scipy.stats import skew, kurtosis
import seaborn as sns
import time
sns.set(style='darkgrid')

# %%
projdir = '/project_cephfs/3022017.02/projects/stijdboe/make_results/10_folds_results/'
data_dir = '/project_cephfs/3022017.02/projects/stijdboe/Data'
folds_dir = os.path.join(data_dir,'10_folds')
python_path = '/project_cephfs/3022017.02/projects/stijdboe/stijn2/bin/python3.10'
normative_path = '/project_cephfs/3022017.02/projects/stijdboe/PCNtoolkit/pcntoolkit/normative.py'

# %%
# For each fold
for i_fold in range(10):
    
    # Load the train and test data
    fold_data_dir = f'/project_cephfs/3022017.02/projects/stijdboe/Data/10_folds_sexcov/fold_{i_fold}'
    with open(os.path.join(fold_data_dir, 'X_train.pkl'),'rb') as file:
              X_train = pickle.load(file)
    with open(os.path.join(fold_data_dir, 'Y_train.pkl'),'rb') as file:
              Y_train = pickle.load(file)
    with open(os.path.join(fold_data_dir, 'Z_train.pkl'),'rb') as file:
              Z_train = pickle.load(file)
    with open(os.path.join(fold_data_dir, 'X_test.pkl'),'rb') as file:
              X_test = pickle.load(file)
    with open(os.path.join(fold_data_dir, 'Y_test.pkl'),'rb') as file:
              Y_test = pickle.load(file)
    with open(os.path.join(fold_data_dir, 'Z_test.pkl'),'rb') as file:
              Z_test = pickle.load(file)

    # For each feature
    features = ['Right-Cerebellum-White-Matter',
                'EstimatedTotalIntraCranialVol',
                'Right-Lateral-Ventricle',
                'WM-hypointensities',
                'rh_S_interm_prim-Jensen_thickness', 
                'Brain-Stem']
    for i_f, feature in enumerate(features):    
        
        # Load that particular data
        this_X_train = X_train.to_numpy()
        this_Y_train = Y_train[feature].to_numpy()
        this_X_test = X_test.to_numpy()
        this_Y_test = Y_test[feature].to_numpy()
        this_Z_test = Z_test.to_numpy()
        
        # Apply in- and outscale to train and test (use util.scaler)
        inscaler = scaler('standardize')
        outscaler = scaler('standardize')
        inscaler.fit(this_X_train)
        outscaler.fit(this_Y_train)
        this_X_test = inscaler.transform(this_X_test)
        this_Y_test = outscaler.transform(this_Y_test)
        
        # For each model type:
        for model_type in ['SHASHb_1','SHASHb_2','Normal']:
            # Load the model
            fold_dir = f'fold_{i_fold}_{model_type}'
            batch_dir = f'batch_{i_f+1}'
            nm_name = f'NM_0_0_estimate1sample.pkl'
            model_path = os.path.join(projdir, fold_dir, batch_dir, 'Models', nm_name)
            if os.path.exists(model_path):
                with open(model_path, 'rb') as file:
                    norm_hbr_model = pickle.load(file)
                # Find the MCMC z-scores
                X_test_transformed = norm_hbr_model.hbr.transform_X(this_X_test)
#                 bspline_transform(this_X_test,norm_hbr_model.hbr.bsp)
                print(f"Computing MAPs for {nm_name}")
                start = time.time()
                map_path = os.path.join(projdir, f"MAPS/MAP_fold{i_fold}_{i_f}_{model_type}.pkl")
                with open(map_path, 'rb') as file:
                    MAP = pickle.load(file)
                print(this_Y_test.shape)
                MCMC_z_scores = get_single_zscores(np.squeeze(X_test_transformed), this_Y_test[:,None], this_Z_test, norm_hbr_model, MAP)[:,0]
                end = time.time()
                print("Found MAP_zscores in ", end-start)
#                 n = np.random.randn(*MCMC_z_scores.shape)
#                 plt.scatter(np.sort(n), np.sort(MCMC_z_scores), alpha = 0.2)
#                 plt.title(f'fold {i_fold}, {feature} {model_type}')
#                 plt.show()
#                 plt.close()
                # Save the MAP
                mcmc_zscoresdir = os.path.join(projdir, fold_dir, batch_dir, 'MAP_zscores')
                if not os.path.exists(mcmc_zscoresdir):
                    os.mkdir(mcmc_zscoresdir)
                with open(os.path.join(mcmc_zscoresdir, f'MAP_zscores_{i_f}_{model_type}_fold{i_fold}.pkl'),'wb') as file:
                    pickle.dump(MCMC_z_scores, file)
# Out:
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05398130416870117
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.0670771598815918
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.015859127044677734
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.057785749435424805
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.058733224868774414
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.016304969787597656
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.10305476188659668
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05876564979553223
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.01547551155090332
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05545473098754883
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05982184410095215
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.015198945999145508
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.0531461238861084
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05780673027038574
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.016123533248901367
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05217790603637695
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05865740776062012
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.015294551849365234
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05317234992980957
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05833148956298828
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.015874385833740234
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05256009101867676
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05927920341491699
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.016563892364501953
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.052962541580200195
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.058860063552856445
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.015851736068725586
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05533862113952637
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.06121063232421875
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.020136594772338867
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.052576303482055664
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.11472749710083008
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.016590118408203125
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.06136655807495117
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.06907939910888672
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.016216039657592773
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.054129600524902344
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05846810340881348
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.04010772705078125
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05573534965515137
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.0589900016784668
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.015714406967163086
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05358481407165527
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.058501482009887695
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.015511274337768555
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.062357425689697266
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.06352448463439941
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.015526294708251953
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05521273612976074
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.0626521110534668
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.01593327522277832
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05295848846435547
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05793166160583496
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.016721248626708984
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05321979522705078
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.058896541595458984
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.016932010650634766
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.0541682243347168
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.0822608470916748
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.01609182357788086
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05313992500305176
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.0595402717590332
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.01579451560974121
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.06379294395446777
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.06042218208312988
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.01598191261291504
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05814790725708008
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.062287330627441406
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.01674818992614746
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05518174171447754
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.0668184757232666
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.01575779914855957
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05311942100524902
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.0586543083190918
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.016402006149291992
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05265974998474121
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.058347225189208984
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.02390599250793457
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05286407470703125
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.06327962875366211
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.015999317169189453
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.054865121841430664
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.060483694076538086
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.015572786331176758
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05355644226074219
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05795884132385254
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.015397787094116211
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05292963981628418
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05941581726074219
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.01581573486328125
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.053508758544921875
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.058680057525634766
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.020123004913330078
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.06117367744445801
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05849432945251465
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.01640009880065918
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.1168520450592041
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.09433150291442871
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.015838623046875
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.09200239181518555
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.0982816219329834
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.015532493591308594
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.0854043960571289
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.09150242805480957
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.025346994400024414
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.10383415222167969
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.11543107032775879
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.018618106842041016
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.15180230140686035
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.08548808097839355
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.05108761787414551
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.2641744613647461
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.09321832656860352
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.021806955337524414
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.09540128707885742
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.14703059196472168
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.03249001502990723
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.12118983268737793
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.15151357650756836
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.018523216247558594
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.10711932182312012
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.08716845512390137
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.057842254638671875
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.12411093711853027
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.1551203727722168
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5767,)
# Found MAP_zscores in  0.04188084602355957
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.08891749382019043
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.2225790023803711
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.07080554962158203
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.1164393424987793
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.11991715431213379
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.04181170463562012
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.13311052322387695
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.137772798538208
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.025063753128051758
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.09208798408508301
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.1480116844177246
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.04336357116699219
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.08223080635070801
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.15114831924438477
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.06395173072814941
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.07655024528503418
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.1443920135498047
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.06453108787536621
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.10576629638671875
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.11276865005493164
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.0391387939453125
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.1234123706817627
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.08619856834411621
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.04323387145996094
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.1901404857635498
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.10102486610412598
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.05996561050415039
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.13276982307434082
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.09746813774108887
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.04513835906982422
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.1073765754699707
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.08269262313842773
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.06249094009399414
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.14749526977539062
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.09416818618774414
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.06623458862304688
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.15076994895935059
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.08699274063110352
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.03595137596130371
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.22258567810058594
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.10378909111022949
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.04403352737426758
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.09364628791809082
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.08456659317016602
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.046594858169555664
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.08608555793762207
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.09525299072265625
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.06580305099487305
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.07544946670532227
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.12189126014709473
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.04212641716003418
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.08701157569885254
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.08177471160888672
# Computing MAPs for NM_0_0_estimate1sample.pkl
# (5766,)
# Found MAP_zscores in  0.06845879554748535
