# %%
import os
import pickle
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import pcntoolkit as ptk
from itertools import product
from functools import reduce
from pcntoolkit.model.SHASH import SHASHb, SHASH, SHASHo
from scipy.stats import gaussian_kde
import scipy.special as spp
import arviz as av
import pymc as pm
from scipy.stats import skew, kurtosis
import seaborn as sns
sns.set(style='darkgrid')

# %%
projdir = '/project_cephfs/3022017.02/projects/stijdboe/make_results/10_folds_results/'
data_dir = '/project_cephfs/3022017.02/projects/stijdboe/Data'
folds_dir = os.path.join(data_dir,'10_folds_sexcov')
python_path = '/home/preclineu/stijdboe/.conda/envs/new_pymc_venv/bin/python'
normative_path = '/home/preclineu/stijdboe/PCNtoolkit/pcntoolkit/normative.py'
results_dir = '/project_cephfs/3022017.02/projects/stijdboe/make_results/10_folds_results'

# %%
features = ['Right-Cerebellum-White-Matter',
            'EstimatedTotalIntraCranialVol',
            'Right-Lateral-Ventricle',
            'WM-hypointensities',
            'rh_S_interm_prim-Jensen_thickness', 
            'Brain-Stem','log_WM-hypointensities']
failed_models = []

for l in ['SHASHo','SHASHb_1','SHASHb_2','Normal']:
    print("==============================================================================")
    for fold in range(10):
        print("--------------------------------------------------")
        for i, f in enumerate(features):
            model_path = os.path.join(results_dir, f'fold_{fold}_{l}',f'batch_{i+1}','Models',f'NM_0_0_estimate.pkl')
            if not os.path.exists(model_path):
                print(f"X Model {l} {f} fold {fold} not found!!!!!!!!!!!!!")
                logdir =  os.path.join(results_dir, f'fold_{fold}_{l}','log')
                # print(features.index(f))
                failed_models.append((fold, l, features.index(f), f))
#                 for file in os.listdir(logdir):
#                     if file.startswith(f'fold_{fold}_{l}_{i+1}.sh.e'):
#                         # Store all failed models as tuples
# #                         print(f"fold {fold}, {l} , {i+1}-{f}")
#                         failed_models.append((fold, l, i, f))
            else:
                print(f"Model {l} {f} fold {fold} found!")
#                     /project_cephfs/3022017.02/projects/stijdboe/make_results/10_folds_results/fold_0_SHASHo2/batch_2/Models/NM_0_0_fold0SHASHo2.pkl
for i in failed_models:
    print(i)
    
print(f"{len(failed_models)} models failed")
# Out:
# ==============================================================================
# --------------------------------------------------
# Model SHASHo Right-Cerebellum-White-Matter fold 0 found!
# Model SHASHo EstimatedTotalIntraCranialVol fold 0 found!
# Model SHASHo Right-Lateral-Ventricle fold 0 found!
# Model SHASHo WM-hypointensities fold 0 found!
# Model SHASHo rh_S_interm_prim-Jensen_thickness fold 0 found!
# Model SHASHo Brain-Stem fold 0 found!
# Model SHASHo log_WM-hypointensities fold 0 found!
# --------------------------------------------------
# Model SHASHo Right-Cerebellum-White-Matter fold 1 found!
# Model SHASHo EstimatedTotalIntraCranialVol fold 1 found!
# Model SHASHo Right-Lateral-Ventricle fold 1 found!
# Model SHASHo WM-hypointensities fold 1 found!
# Model SHASHo rh_S_interm_prim-Jensen_thickness fold 1 found!
# Model SHASHo Brain-Stem fold 1 found!
# Model SHASHo log_WM-hypointensities fold 1 found!
# --------------------------------------------------
# Model SHASHo Right-Cerebellum-White-Matter fold 2 found!
# Model SHASHo EstimatedTotalIntraCranialVol fold 2 found!
# Model SHASHo Right-Lateral-Ventricle fold 2 found!
# Model SHASHo WM-hypointensities fold 2 found!
# Model SHASHo rh_S_interm_prim-Jensen_thickness fold 2 found!
# Model SHASHo Brain-Stem fold 2 found!
# Model SHASHo log_WM-hypointensities fold 2 found!
# --------------------------------------------------
# Model SHASHo Right-Cerebellum-White-Matter fold 3 found!
# Model SHASHo EstimatedTotalIntraCranialVol fold 3 found!
# Model SHASHo Right-Lateral-Ventricle fold 3 found!
# Model SHASHo WM-hypointensities fold 3 found!
# Model SHASHo rh_S_interm_prim-Jensen_thickness fold 3 found!
# Model SHASHo Brain-Stem fold 3 found!
# Model SHASHo log_WM-hypointensities fold 3 found!
# --------------------------------------------------
# Model SHASHo Right-Cerebellum-White-Matter fold 4 found!
# Model SHASHo EstimatedTotalIntraCranialVol fold 4 found!
# Model SHASHo Right-Lateral-Ventricle fold 4 found!
# Model SHASHo WM-hypointensities fold 4 found!
# Model SHASHo rh_S_interm_prim-Jensen_thickness fold 4 found!
# Model SHASHo Brain-Stem fold 4 found!
# Model SHASHo log_WM-hypointensities fold 4 found!
# --------------------------------------------------
# Model SHASHo Right-Cerebellum-White-Matter fold 5 found!
# Model SHASHo EstimatedTotalIntraCranialVol fold 5 found!
# Model SHASHo Right-Lateral-Ventricle fold 5 found!
# Model SHASHo WM-hypointensities fold 5 found!
# Model SHASHo rh_S_interm_prim-Jensen_thickness fold 5 found!
# Model SHASHo Brain-Stem fold 5 found!
# Model SHASHo log_WM-hypointensities fold 5 found!
# --------------------------------------------------
# Model SHASHo Right-Cerebellum-White-Matter fold 6 found!
# Model SHASHo EstimatedTotalIntraCranialVol fold 6 found!
# Model SHASHo Right-Lateral-Ventricle fold 6 found!
# Model SHASHo WM-hypointensities fold 6 found!
# Model SHASHo rh_S_interm_prim-Jensen_thickness fold 6 found!
# Model SHASHo Brain-Stem fold 6 found!
# Model SHASHo log_WM-hypointensities fold 6 found!
# --------------------------------------------------
# Model SHASHo Right-Cerebellum-White-Matter fold 7 found!
# Model SHASHo EstimatedTotalIntraCranialVol fold 7 found!
# Model SHASHo Right-Lateral-Ventricle fold 7 found!
# Model SHASHo WM-hypointensities fold 7 found!
# Model SHASHo rh_S_interm_prim-Jensen_thickness fold 7 found!
# Model SHASHo Brain-Stem fold 7 found!
# Model SHASHo log_WM-hypointensities fold 7 found!
# --------------------------------------------------
# Model SHASHo Right-Cerebellum-White-Matter fold 8 found!
# Model SHASHo EstimatedTotalIntraCranialVol fold 8 found!
# Model SHASHo Right-Lateral-Ventricle fold 8 found!
# Model SHASHo WM-hypointensities fold 8 found!
# Model SHASHo rh_S_interm_prim-Jensen_thickness fold 8 found!
# Model SHASHo Brain-Stem fold 8 found!
# Model SHASHo log_WM-hypointensities fold 8 found!
# --------------------------------------------------
# Model SHASHo Right-Cerebellum-White-Matter fold 9 found!
# Model SHASHo EstimatedTotalIntraCranialVol fold 9 found!
# Model SHASHo Right-Lateral-Ventricle fold 9 found!
# Model SHASHo WM-hypointensities fold 9 found!
# Model SHASHo rh_S_interm_prim-Jensen_thickness fold 9 found!
# Model SHASHo Brain-Stem fold 9 found!
# Model SHASHo log_WM-hypointensities fold 9 found!
# ==============================================================================
# --------------------------------------------------
# Model SHASHb_1 Right-Cerebellum-White-Matter fold 0 found!
# Model SHASHb_1 EstimatedTotalIntraCranialVol fold 0 found!
# Model SHASHb_1 Right-Lateral-Ventricle fold 0 found!
# Model SHASHb_1 WM-hypointensities fold 0 found!
# Model SHASHb_1 rh_S_interm_prim-Jensen_thickness fold 0 found!
# Model SHASHb_1 Brain-Stem fold 0 found!
# Model SHASHb_1 log_WM-hypointensities fold 0 found!
# --------------------------------------------------
# Model SHASHb_1 Right-Cerebellum-White-Matter fold 1 found!
# Model SHASHb_1 EstimatedTotalIntraCranialVol fold 1 found!
# Model SHASHb_1 Right-Lateral-Ventricle fold 1 found!
# Model SHASHb_1 WM-hypointensities fold 1 found!
# Model SHASHb_1 rh_S_interm_prim-Jensen_thickness fold 1 found!
# Model SHASHb_1 Brain-Stem fold 1 found!
# Model SHASHb_1 log_WM-hypointensities fold 1 found!
# --------------------------------------------------
# Model SHASHb_1 Right-Cerebellum-White-Matter fold 2 found!
# Model SHASHb_1 EstimatedTotalIntraCranialVol fold 2 found!
# Model SHASHb_1 Right-Lateral-Ventricle fold 2 found!
# Model SHASHb_1 WM-hypointensities fold 2 found!
# Model SHASHb_1 rh_S_interm_prim-Jensen_thickness fold 2 found!
# Model SHASHb_1 Brain-Stem fold 2 found!
# Model SHASHb_1 log_WM-hypointensities fold 2 found!
# --------------------------------------------------
# Model SHASHb_1 Right-Cerebellum-White-Matter fold 3 found!
# Model SHASHb_1 EstimatedTotalIntraCranialVol fold 3 found!
# Model SHASHb_1 Right-Lateral-Ventricle fold 3 found!
# Model SHASHb_1 WM-hypointensities fold 3 found!
# Model SHASHb_1 rh_S_interm_prim-Jensen_thickness fold 3 found!
# Model SHASHb_1 Brain-Stem fold 3 found!
# Model SHASHb_1 log_WM-hypointensities fold 3 found!
# --------------------------------------------------
# Model SHASHb_1 Right-Cerebellum-White-Matter fold 4 found!
# Model SHASHb_1 EstimatedTotalIntraCranialVol fold 4 found!
# Model SHASHb_1 Right-Lateral-Ventricle fold 4 found!
# Model SHASHb_1 WM-hypointensities fold 4 found!
# Model SHASHb_1 rh_S_interm_prim-Jensen_thickness fold 4 found!
# Model SHASHb_1 Brain-Stem fold 4 found!
# Model SHASHb_1 log_WM-hypointensities fold 4 found!
# --------------------------------------------------
# Model SHASHb_1 Right-Cerebellum-White-Matter fold 5 found!
# Model SHASHb_1 EstimatedTotalIntraCranialVol fold 5 found!
# Model SHASHb_1 Right-Lateral-Ventricle fold 5 found!
# Model SHASHb_1 WM-hypointensities fold 5 found!
# Model SHASHb_1 rh_S_interm_prim-Jensen_thickness fold 5 found!
# Model SHASHb_1 Brain-Stem fold 5 found!
# Model SHASHb_1 log_WM-hypointensities fold 5 found!
# --------------------------------------------------
# Model SHASHb_1 Right-Cerebellum-White-Matter fold 6 found!
# Model SHASHb_1 EstimatedTotalIntraCranialVol fold 6 found!
# Model SHASHb_1 Right-Lateral-Ventricle fold 6 found!
# Model SHASHb_1 WM-hypointensities fold 6 found!
# Model SHASHb_1 rh_S_interm_prim-Jensen_thickness fold 6 found!
# Model SHASHb_1 Brain-Stem fold 6 found!
# Model SHASHb_1 log_WM-hypointensities fold 6 found!
# --------------------------------------------------
# Model SHASHb_1 Right-Cerebellum-White-Matter fold 7 found!
# Model SHASHb_1 EstimatedTotalIntraCranialVol fold 7 found!
# Model SHASHb_1 Right-Lateral-Ventricle fold 7 found!
# Model SHASHb_1 WM-hypointensities fold 7 found!
# Model SHASHb_1 rh_S_interm_prim-Jensen_thickness fold 7 found!
# Model SHASHb_1 Brain-Stem fold 7 found!
# Model SHASHb_1 log_WM-hypointensities fold 7 found!
# --------------------------------------------------
# Model SHASHb_1 Right-Cerebellum-White-Matter fold 8 found!
# Model SHASHb_1 EstimatedTotalIntraCranialVol fold 8 found!
# Model SHASHb_1 Right-Lateral-Ventricle fold 8 found!
# Model SHASHb_1 WM-hypointensities fold 8 found!
# Model SHASHb_1 rh_S_interm_prim-Jensen_thickness fold 8 found!
# Model SHASHb_1 Brain-Stem fold 8 found!
# Model SHASHb_1 log_WM-hypointensities fold 8 found!
# --------------------------------------------------
# Model SHASHb_1 Right-Cerebellum-White-Matter fold 9 found!
# Model SHASHb_1 EstimatedTotalIntraCranialVol fold 9 found!
# Model SHASHb_1 Right-Lateral-Ventricle fold 9 found!
# Model SHASHb_1 WM-hypointensities fold 9 found!
# Model SHASHb_1 rh_S_interm_prim-Jensen_thickness fold 9 found!
# Model SHASHb_1 Brain-Stem fold 9 found!
# Model SHASHb_1 log_WM-hypointensities fold 9 found!
# ==============================================================================
# --------------------------------------------------
# Model SHASHb_2 Right-Cerebellum-White-Matter fold 0 found!
# Model SHASHb_2 EstimatedTotalIntraCranialVol fold 0 found!
# Model SHASHb_2 Right-Lateral-Ventricle fold 0 found!
# Model SHASHb_2 WM-hypointensities fold 0 found!
# Model SHASHb_2 rh_S_interm_prim-Jensen_thickness fold 0 found!
# Model SHASHb_2 Brain-Stem fold 0 found!
# Model SHASHb_2 log_WM-hypointensities fold 0 found!
# --------------------------------------------------
# Model SHASHb_2 Right-Cerebellum-White-Matter fold 1 found!
# Model SHASHb_2 EstimatedTotalIntraCranialVol fold 1 found!
# Model SHASHb_2 Right-Lateral-Ventricle fold 1 found!
# Model SHASHb_2 WM-hypointensities fold 1 found!
# Model SHASHb_2 rh_S_interm_prim-Jensen_thickness fold 1 found!
# Model SHASHb_2 Brain-Stem fold 1 found!
# Model SHASHb_2 log_WM-hypointensities fold 1 found!
# --------------------------------------------------
# Model SHASHb_2 Right-Cerebellum-White-Matter fold 2 found!
# Model SHASHb_2 EstimatedTotalIntraCranialVol fold 2 found!
# Model SHASHb_2 Right-Lateral-Ventricle fold 2 found!
# Model SHASHb_2 WM-hypointensities fold 2 found!
# Model SHASHb_2 rh_S_interm_prim-Jensen_thickness fold 2 found!
# Model SHASHb_2 Brain-Stem fold 2 found!
# Model SHASHb_2 log_WM-hypointensities fold 2 found!
# --------------------------------------------------
# Model SHASHb_2 Right-Cerebellum-White-Matter fold 3 found!
# Model SHASHb_2 EstimatedTotalIntraCranialVol fold 3 found!
# Model SHASHb_2 Right-Lateral-Ventricle fold 3 found!
# Model SHASHb_2 WM-hypointensities fold 3 found!
# Model SHASHb_2 rh_S_interm_prim-Jensen_thickness fold 3 found!
# Model SHASHb_2 Brain-Stem fold 3 found!
# Model SHASHb_2 log_WM-hypointensities fold 3 found!
# --------------------------------------------------
# Model SHASHb_2 Right-Cerebellum-White-Matter fold 4 found!
# Model SHASHb_2 EstimatedTotalIntraCranialVol fold 4 found!
# Model SHASHb_2 Right-Lateral-Ventricle fold 4 found!
# Model SHASHb_2 WM-hypointensities fold 4 found!
# Model SHASHb_2 rh_S_interm_prim-Jensen_thickness fold 4 found!
# Model SHASHb_2 Brain-Stem fold 4 found!
# Model SHASHb_2 log_WM-hypointensities fold 4 found!
# --------------------------------------------------
# Model SHASHb_2 Right-Cerebellum-White-Matter fold 5 found!
# Model SHASHb_2 EstimatedTotalIntraCranialVol fold 5 found!
# Model SHASHb_2 Right-Lateral-Ventricle fold 5 found!
# Model SHASHb_2 WM-hypointensities fold 5 found!
# Model SHASHb_2 rh_S_interm_prim-Jensen_thickness fold 5 found!
# Model SHASHb_2 Brain-Stem fold 5 found!
# Model SHASHb_2 log_WM-hypointensities fold 5 found!
# --------------------------------------------------
# Model SHASHb_2 Right-Cerebellum-White-Matter fold 6 found!
# Model SHASHb_2 EstimatedTotalIntraCranialVol fold 6 found!
# Model SHASHb_2 Right-Lateral-Ventricle fold 6 found!
# Model SHASHb_2 WM-hypointensities fold 6 found!
# Model SHASHb_2 rh_S_interm_prim-Jensen_thickness fold 6 found!
# Model SHASHb_2 Brain-Stem fold 6 found!
# Model SHASHb_2 log_WM-hypointensities fold 6 found!
# --------------------------------------------------
# Model SHASHb_2 Right-Cerebellum-White-Matter fold 7 found!
# Model SHASHb_2 EstimatedTotalIntraCranialVol fold 7 found!
# Model SHASHb_2 Right-Lateral-Ventricle fold 7 found!
# Model SHASHb_2 WM-hypointensities fold 7 found!
# Model SHASHb_2 rh_S_interm_prim-Jensen_thickness fold 7 found!
# Model SHASHb_2 Brain-Stem fold 7 found!
# Model SHASHb_2 log_WM-hypointensities fold 7 found!
# --------------------------------------------------
# Model SHASHb_2 Right-Cerebellum-White-Matter fold 8 found!
# Model SHASHb_2 EstimatedTotalIntraCranialVol fold 8 found!
# Model SHASHb_2 Right-Lateral-Ventricle fold 8 found!
# Model SHASHb_2 WM-hypointensities fold 8 found!
# Model SHASHb_2 rh_S_interm_prim-Jensen_thickness fold 8 found!
# Model SHASHb_2 Brain-Stem fold 8 found!
# Model SHASHb_2 log_WM-hypointensities fold 8 found!
# --------------------------------------------------
# Model SHASHb_2 Right-Cerebellum-White-Matter fold 9 found!
# Model SHASHb_2 EstimatedTotalIntraCranialVol fold 9 found!
# Model SHASHb_2 Right-Lateral-Ventricle fold 9 found!
# Model SHASHb_2 WM-hypointensities fold 9 found!
# Model SHASHb_2 rh_S_interm_prim-Jensen_thickness fold 9 found!
# Model SHASHb_2 Brain-Stem fold 9 found!
# Model SHASHb_2 log_WM-hypointensities fold 9 found!
# ==============================================================================
# --------------------------------------------------
# Model Normal Right-Cerebellum-White-Matter fold 0 found!
# Model Normal EstimatedTotalIntraCranialVol fold 0 found!
# Model Normal Right-Lateral-Ventricle fold 0 found!
# Model Normal WM-hypointensities fold 0 found!
# Model Normal rh_S_interm_prim-Jensen_thickness fold 0 found!
# Model Normal Brain-Stem fold 0 found!
# Model Normal log_WM-hypointensities fold 0 found!
# --------------------------------------------------
# Model Normal Right-Cerebellum-White-Matter fold 1 found!
# Model Normal EstimatedTotalIntraCranialVol fold 1 found!
# Model Normal Right-Lateral-Ventricle fold 1 found!
# Model Normal WM-hypointensities fold 1 found!
# Model Normal rh_S_interm_prim-Jensen_thickness fold 1 found!
# Model Normal Brain-Stem fold 1 found!
# Model Normal log_WM-hypointensities fold 1 found!
# --------------------------------------------------
# Model Normal Right-Cerebellum-White-Matter fold 2 found!
# Model Normal EstimatedTotalIntraCranialVol fold 2 found!
# Model Normal Right-Lateral-Ventricle fold 2 found!
# Model Normal WM-hypointensities fold 2 found!
# Model Normal rh_S_interm_prim-Jensen_thickness fold 2 found!
# Model Normal Brain-Stem fold 2 found!
# Model Normal log_WM-hypointensities fold 2 found!
# --------------------------------------------------
# Model Normal Right-Cerebellum-White-Matter fold 3 found!
# Model Normal EstimatedTotalIntraCranialVol fold 3 found!
# Model Normal Right-Lateral-Ventricle fold 3 found!
# Model Normal WM-hypointensities fold 3 found!
# Model Normal rh_S_interm_prim-Jensen_thickness fold 3 found!
# Model Normal Brain-Stem fold 3 found!
# Model Normal log_WM-hypointensities fold 3 found!
# --------------------------------------------------
# Model Normal Right-Cerebellum-White-Matter fold 4 found!
# Model Normal EstimatedTotalIntraCranialVol fold 4 found!
# Model Normal Right-Lateral-Ventricle fold 4 found!
# Model Normal WM-hypointensities fold 4 found!
# Model Normal rh_S_interm_prim-Jensen_thickness fold 4 found!
# Model Normal Brain-Stem fold 4 found!
# Model Normal log_WM-hypointensities fold 4 found!
# --------------------------------------------------
# Model Normal Right-Cerebellum-White-Matter fold 5 found!
# Model Normal EstimatedTotalIntraCranialVol fold 5 found!
# Model Normal Right-Lateral-Ventricle fold 5 found!
# Model Normal WM-hypointensities fold 5 found!
# Model Normal rh_S_interm_prim-Jensen_thickness fold 5 found!
# Model Normal Brain-Stem fold 5 found!
# Model Normal log_WM-hypointensities fold 5 found!
# --------------------------------------------------
# Model Normal Right-Cerebellum-White-Matter fold 6 found!
# Model Normal EstimatedTotalIntraCranialVol fold 6 found!
# Model Normal Right-Lateral-Ventricle fold 6 found!
# Model Normal WM-hypointensities fold 6 found!
# Model Normal rh_S_interm_prim-Jensen_thickness fold 6 found!
# Model Normal Brain-Stem fold 6 found!
# Model Normal log_WM-hypointensities fold 6 found!
# --------------------------------------------------
# Model Normal Right-Cerebellum-White-Matter fold 7 found!
# Model Normal EstimatedTotalIntraCranialVol fold 7 found!
# Model Normal Right-Lateral-Ventricle fold 7 found!
# Model Normal WM-hypointensities fold 7 found!
# Model Normal rh_S_interm_prim-Jensen_thickness fold 7 found!
# Model Normal Brain-Stem fold 7 found!
# Model Normal log_WM-hypointensities fold 7 found!
# --------------------------------------------------
# Model Normal Right-Cerebellum-White-Matter fold 8 found!
# Model Normal EstimatedTotalIntraCranialVol fold 8 found!
# Model Normal Right-Lateral-Ventricle fold 8 found!
# Model Normal WM-hypointensities fold 8 found!
# Model Normal rh_S_interm_prim-Jensen_thickness fold 8 found!
# Model Normal Brain-Stem fold 8 found!
# Model Normal log_WM-hypointensities fold 8 found!
# --------------------------------------------------
# Model Normal Right-Cerebellum-White-Matter fold 9 found!
# Model Normal EstimatedTotalIntraCranialVol fold 9 found!
# Model Normal Right-Lateral-Ventricle fold 9 found!
# Model Normal WM-hypointensities fold 9 found!
# Model Normal rh_S_interm_prim-Jensen_thickness fold 9 found!
# Model Normal Brain-Stem fold 9 found!
# Model Normal log_WM-hypointensities fold 9 found!
# 0 models failed

# %% [markdown]
# - 3-5-2023 - 30 models failed before move - 14 models failed after move
# - 5-5-2023 - 14 models failed before move - 8 models failed after move
# - 8-5-2023 - 8 models failed before move - 7 models failed after move
# - 11-5-2023 - 7 models failed before move - 8 models failed after move
#     - (3, 'SHASHo', 4, 'rh_S_interm_prim-Jensen_thickness')
#     - (4, 'SHASHb_2', 1, 'EstimatedTotalIntraCranialVol')
#     - (4, 'SHASHb_2', 2, 'Right-Lateral-Ventricle')
#     - (4, 'SHASHb_2', 3, 'WM-hypointensities')
#     - (4, 'SHASHb_2', 4, 'rh_S_interm_prim-Jensen_thickness')
#     - (7, 'SHASHb_2', 3, 'WM-hypointensities')
#     - (7, 'SHASHb_2', 5, 'Brain-Stem')
#     - (9, 'SHASHb_2', 4, 'rh_S_interm_prim-Jensen_thickness')

# %%
# del failed_models[1]
# del failed_models[1]

# print(failed_models)
# failed_models = [(0, 'SHASHb_2', 4, 'rh_S_interm_prim-Jensen_thickness')]
# print(failed_models)

# failed_models = [(4, 'SHASHb_2', 1, 'EstimatedTotalIntraCranialVol'),
#                  (4, 'SHASHb_2', 4, 'rh_S_interm_prim-Jensen_thickness'),
#                  (7, 'SHASHb_2', 3, 'WM-hypointensities'),
#                  (7, 'SHASHb_2', 5, 'Brain-Stem'), 
#                  (9, 'SHASHb_2', 4, 'rh_S_interm_prim-Jensen_thickness')]

# %%
batch_size= 1
n_chains= '2'
n_cores_per_batch= '4'  # <- this specifies the number of cores for the job
cores = '4'           # <- this specifies the number of cores for pymc3
n_samples = '1000'
n_tuning='500'
memory = '20gb'
inscaler = 'standardize'
outscaler = 'standardize'

method='bspline'

linear_mu = 'True'
random_intercept_mu='True'
linear_sigma   = 'True'

target_accept = '0.99'

# %%
# For each failed model
model_names = ['SHASHo','SHASHb_1','SHASHb_2','Normal']
likelihood_map = {'SHASHb_1':'SHASHb','SHASHb_2':'SHASHb','SHASHo':'SHASHo','Normal':'Normal'}
durationmap = {'Normal':'12:00:00','SHASHb':'50:00:00','SHASHo':'25:00:00'}
epsilon_linear_map = {'SHASHb_1':'False','SHASHb_2':'True','Normal':'False','SHASHo':'False'}
delta_linear_map = {'SHASHb_1':'False','SHASHb_2':'True','Normal':'False','SHASHo':'False'}


for fold, model_name, feature_i, feature in failed_models:
    likelihood = likelihood_map[model_name]
    duration = durationmap[likelihood]
    linear_epsilon = epsilon_linear_map[model_name]
    linear_delta = delta_linear_map[model_name]
    
    # Unpack the featurename and foldname
    this_identifier = f"patch_fold_{fold}_{model_name}_{feature_i+1}"
    job_name = this_identifier
    fold_dir = os.path.join(folds_dir,f'fold_{fold}')
    processing_dir = os.path.join(projdir, this_identifier+'/')
    if not os.path.exists(processing_dir):
        os.mkdir(processing_dir)

    log_dir = os.path.join(processing_dir, 'log')           #
    if not os.path.isdir(log_dir):
        os.mkdir(log_dir)

    # The paths to the data
    X_path = os.path.join(folds_dir, f'fold_{fold}', 'X_train.pkl')
    Y_path = os.path.join(folds_dir, f'fold_{fold}', 'Y_train.pkl')
    Z_path = os.path.join(folds_dir, f'fold_{fold}', 'Z_train.pkl')
    
    # Check if the fold-feature has been stored already
    patch_fold_feature_data_path = os.path.join(data_dir,'patch_data',f'patch_fold-{fold}_{feature}.pkl')
    
    # Check if the fold-feature has been stored already
    if not os.path.exists(patch_fold_feature_data_path):
        print("Patch data not found")
        with open(Y_path, 'rb') as file:
            Y = pickle.load(file)
            Y_patch = Y[feature]
        with open(patch_fold_feature_data_path,'wb') as file:
            pickle.dump(Y_patch, file)
    print(fold, likelihood, duration, feature)
    ptk.normative_parallel.execute_nm(processing_dir=processing_dir,
                                          python_path=python_path,
                                          normative_path=normative_path,
                                          job_name = job_name,
                                          n_cores_per_batch = n_cores_per_batch,
                                          cores=cores,
                                          memory=memory,
                                          duration=duration,
                                          batch_size= batch_size,
                                          
                                          savemodel='True',
                                          outputsuffix='estimate',
                                          log_path=log_dir,
                                          binary=True,
                                 
                                          covfile_path=X_path,
                                          respfile_path=patch_fold_feature_data_path,
                                          trbefile=Z_path,
        
                                          alg='hbr',
                                          func='fit',
                                          inscaler=inscaler,
                                          outscaler=outscaler, 
                                          model_type=method,
 
                                          likelihood = likelihood,
                                          linear_mu=linear_mu,
                                          random_intercept_mu=random_intercept_mu,
                                      
                                          random_slope_mu = 'False',
                                          random_sigma='False',
                                          random_intercept_sigma='False',
                                          random_slope_sigma='False',
                                          linear_sigma=linear_sigma,
                                          linear_epsilon=linear_epsilon,
                                          linear_delta=linear_delta,
                                          target_accept = target_accept,
                                          
                                          n_samples=n_samples,
                                          n_tuning=n_tuning,
                                          n_chains=n_chains,
                                          interactive=False)
# Out:
# 0 SHASHb 50:00:00 Right-Cerebellum-White-Matter
# 0 SHASHb 50:00:00 EstimatedTotalIntraCranialVol
# 0 SHASHb 50:00:00 Right-Lateral-Ventricle
# 0 SHASHb 50:00:00 WM-hypointensities
# 0 SHASHb 50:00:00 rh_S_interm_prim-Jensen_thickness
# 0 SHASHb 50:00:00 Brain-Stem
# 0 SHASHb 50:00:00 log_WM-hypointensities
# 1 SHASHb 50:00:00 Right-Cerebellum-White-Matter
# 1 SHASHb 50:00:00 EstimatedTotalIntraCranialVol
# 1 SHASHb 50:00:00 Right-Lateral-Ventricle
# 1 SHASHb 50:00:00 WM-hypointensities
# 1 SHASHb 50:00:00 rh_S_interm_prim-Jensen_thickness
# 1 SHASHb 50:00:00 Brain-Stem
# 1 SHASHb 50:00:00 log_WM-hypointensities
# 2 SHASHb 50:00:00 Right-Cerebellum-White-Matter
# 2 SHASHb 50:00:00 EstimatedTotalIntraCranialVol
# 2 SHASHb 50:00:00 Right-Lateral-Ventricle
# 2 SHASHb 50:00:00 WM-hypointensities
# 2 SHASHb 50:00:00 rh_S_interm_prim-Jensen_thickness
# 2 SHASHb 50:00:00 Brain-Stem
# 2 SHASHb 50:00:00 log_WM-hypointensities
# 3 SHASHb 50:00:00 Right-Cerebellum-White-Matter
# 3 SHASHb 50:00:00 EstimatedTotalIntraCranialVol
# 3 SHASHb 50:00:00 Right-Lateral-Ventricle
# 3 SHASHb 50:00:00 WM-hypointensities
# 3 SHASHb 50:00:00 rh_S_interm_prim-Jensen_thickness
# 3 SHASHb 50:00:00 Brain-Stem
# 3 SHASHb 50:00:00 log_WM-hypointensities
# 4 SHASHb 50:00:00 Right-Cerebellum-White-Matter
# 4 SHASHb 50:00:00 EstimatedTotalIntraCranialVol
# 4 SHASHb 50:00:00 Right-Lateral-Ventricle
# 4 SHASHb 50:00:00 WM-hypointensities
# 4 SHASHb 50:00:00 rh_S_interm_prim-Jensen_thickness
# 4 SHASHb 50:00:00 Brain-Stem
# 4 SHASHb 50:00:00 log_WM-hypointensities
# 5 SHASHb 50:00:00 Right-Cerebellum-White-Matter
# 5 SHASHb 50:00:00 EstimatedTotalIntraCranialVol
# 5 SHASHb 50:00:00 Right-Lateral-Ventricle
# 5 SHASHb 50:00:00 WM-hypointensities
# 5 SHASHb 50:00:00 rh_S_interm_prim-Jensen_thickness
# 5 SHASHb 50:00:00 Brain-Stem
# 5 SHASHb 50:00:00 log_WM-hypointensities
# 6 SHASHb 50:00:00 Right-Cerebellum-White-Matter
# 6 SHASHb 50:00:00 EstimatedTotalIntraCranialVol
# 6 SHASHb 50:00:00 Right-Lateral-Ventricle
# 6 SHASHb 50:00:00 WM-hypointensities
# 6 SHASHb 50:00:00 rh_S_interm_prim-Jensen_thickness
# 6 SHASHb 50:00:00 Brain-Stem
# 6 SHASHb 50:00:00 log_WM-hypointensities
# 7 SHASHb 50:00:00 Right-Cerebellum-White-Matter
# 7 SHASHb 50:00:00 EstimatedTotalIntraCranialVol
# 7 SHASHb 50:00:00 Right-Lateral-Ventricle
# 7 SHASHb 50:00:00 WM-hypointensities
# 7 SHASHb 50:00:00 rh_S_interm_prim-Jensen_thickness
# 7 SHASHb 50:00:00 Brain-Stem
# 7 SHASHb 50:00:00 log_WM-hypointensities
# 8 SHASHb 50:00:00 Right-Cerebellum-White-Matter
# 8 SHASHb 50:00:00 EstimatedTotalIntraCranialVol
# 8 SHASHb 50:00:00 Right-Lateral-Ventricle
# 8 SHASHb 50:00:00 WM-hypointensities
# 8 SHASHb 50:00:00 rh_S_interm_prim-Jensen_thickness
# 8 SHASHb 50:00:00 Brain-Stem
# 8 SHASHb 50:00:00 log_WM-hypointensities
# 9 SHASHb 50:00:00 Right-Cerebellum-White-Matter
# 9 SHASHb 50:00:00 EstimatedTotalIntraCranialVol
# 9 SHASHb 50:00:00 Right-Lateral-Ventricle
# 9 SHASHb 50:00:00 WM-hypointensities
# 9 SHASHb 50:00:00 rh_S_interm_prim-Jensen_thickness
# 9 SHASHb 50:00:00 Brain-Stem
# 9 SHASHb 50:00:00 log_WM-hypointensities

# %%
"make_results/10_folds_results/fold_0_SHASHb_2/batch_1/Models"
"make_results/10_folds_results/patch_fold_0_SHASHb_2_1/batch_1/Models"
import shutil

for i in os.listdir("/project_cephfs/3022017.02/projects/stijdboe/make_results/10_folds_results"):
    if i.startswith('patch'):
        split = i.split("_")
        fold = split[2]
        model = split[3]
        if model == 'SHASHb':
            model = model  + "_"+split[4]
        batch = split[-1]
        model_to_copy_path =os.path.join("/project_cephfs/3022017.02/projects/stijdboe/make_results/10_folds_results", i, 'batch_1', 'Models', 'NM_0_0_estimate.pkl')
        if os.path.exists(model_to_copy_path):
            pass
            print(i + "found")
            target_dest = os.path.join("/project_cephfs/3022017.02/projects/stijdboe/make_results/10_folds_results", 'fold_'+fold+'_'+model, 'batch_'+batch, 'Models', 'NM_0_0_estimate.pkl')
            shutil.copyfile(model_to_copy_path, target_dest)
        else:
            print("X " +i + "not found")
# Out:
# X patch_fold_8_SHASHb_2_7not found
# X patch_fold_0_SHASHb_2_2not found
# X patch_fold_3_SHASHb_2_4not found
# X patch_fold_6_SHASHb_2_1not found
# X patch_fold_3_SHASHb_2_1not found
# X patch_fold_2_SHASHb_2_1not found
# X patch_fold_6_SHASHb_2_5not found
# X patch_fold_7_SHASHb_2_1not found
# X patch_fold_3_SHASHb_2_3not found
# X patch_fold_2_SHASHb_2_3not found
# X patch_fold_8_SHASHb_2_5not found
# X patch_fold_6_SHASHb_2_7not found
# X patch_fold_1_SHASHb_2_4not found
# X patch_fold_4_SHASHb_2_5not found
# X patch_fold_5_SHASHb_2_3not found
# X patch_fold_0_SHASHb_2_7not found
# X patch_fold_9_SHASHb_2_4not found
# X patch_fold_8_SHASHb_2_4not found
# X patch_fold_1_SHASHb_2_7not found
# X patch_fold_4_SHASHb_2_6not found
# X patch_fold_2_SHASHb_2_5not found
# X patch_fold_1_SHASHb_2_1not found
# X patch_fold_8_SHASHb_2_1not found
# X patch_fold_2_SHASHb_2_2not found
# X patch_fold_3_SHASHb_2_6not found
# X patch_fold_6_SHASHb_2_4not found
# X patch_fold_7_SHASHb_2_7not found
# X patch_fold_0_SHASHb_2_3not found
# X patch_fold_4_SHASHb_2_1not found
# X patch_fold_4_SHASHb_2_7not found
# X patch_fold_9_SHASHb_2_6not found
# X patch_fold_1_SHASHb_2_3not found
# X patch_fold_1_SHASHb_2_6not found
# X patch_fold_0_SHASHb_2_6not found
# X patch_fold_5_SHASHb_2_7not found
# X patch_fold_3_SHASHb_2_7not found
# X patch_fold_4_SHASHb_2_3not found
# X patch_fold_5_SHASHb_2_4not found
# X patch_fold_6_SHASHb_2_3not found
# X patch_fold_9_SHASHb_2_3not found
# X patch_fold_3_SHASHb_2_5not found
# X patch_fold_2_SHASHb_2_6not found
# X patch_fold_9_SHASHb_2_2not found
# X patch_fold_1_SHASHb_2_5not found
# X patch_fold_6_SHASHb_2_6not found
# X patch_fold_5_SHASHb_2_2not found
# X patch_fold_4_SHASHb_2_4not found
# X patch_fold_7_SHASHb_2_6not found
# X patch_fold_5_SHASHb_2_1not found
# X patch_fold_7_SHASHb_2_4not found
# X patch_fold_7_SHASHb_2_2not found
# X patch_fold_5_SHASHb_2_6not found
# X patch_fold_6_SHASHb_2_2not found
# X patch_fold_2_SHASHb_2_4not found
# X patch_fold_3_SHASHb_2_2not found
# X patch_fold_0_SHASHb_2_4not found
# X patch_fold_9_SHASHb_2_7not found
# X patch_fold_7_SHASHb_2_3not found
# X patch_fold_0_SHASHb_2_5not found
# X patch_fold_0_SHASHb_2_1not found
# X patch_fold_8_SHASHb_2_3not found
# X patch_fold_2_SHASHb_2_7not found
# X patch_fold_8_SHASHb_2_6not found
# X patch_fold_9_SHASHb_2_1not found
# X patch_fold_1_SHASHb_2_2not found
# X patch_fold_4_SHASHb_2_2not found
# X patch_fold_7_SHASHb_2_5not found
# X patch_fold_5_SHASHb_2_5not found
# X patch_fold_9_SHASHb_2_5not found
# X patch_fold_8_SHASHb_2_2not found

# %%
print("ploep")
# Out:
# ploep
